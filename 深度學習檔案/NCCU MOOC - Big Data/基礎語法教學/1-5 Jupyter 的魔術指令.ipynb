# %% [markdown]
# 所有魔術指令前面都以%開頭

# %%
# %pylab inline 
# 進行繪圖的圖形會顯示在瀏覽器中(以後不要用的魔術指令)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
# 畫(0,2),(1,10),(2,3),(3,13),(4,5)這幾個點依照 x值由大到小連起來
plot([-2,10,3,13,5])

# %%
# numpy 亂數指令
 
randn(10) # randn(隨機數字的個數,平均數是0，標準差是1)
# Out:
# array([-0.41630964, -1.72557624,  0.45238364,  1.11967142, -0.41157071,
#        -0.22924749,  1.21554129,  0.69054009,  0.99485989,  0.64287531])

# %%
plot(randn(100))

# %%
plot(randn(50))

# %%
plot([-2,1,2.7,3.3],[3,-5,6,0])
