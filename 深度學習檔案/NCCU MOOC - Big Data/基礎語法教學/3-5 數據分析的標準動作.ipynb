# %% [markdown]
# ## 數據分析的標準動作
# * %matplotlib inline
# * import numpy as np
# * import matplotlib.pyplot as plt
#
# 用 tab 鍵可以自動補完剩下的指令

# %%
# 讓 Jupyter notebook能夠出現 matplotlib的圖
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([3,-4,1,5,-2,7,3,-5,6])

# %%
plt.plot(np.random.randn(100))
